# %% [markdown]
# # K-Fashion-MMDetection
#
# 경기대학교 2022-2 오픈소스SW실습 4조 최종 과제
#
# | 구분 | 학과         | 학번      | 이름   |
# | ---- | ------------ | --------- | ------ |
# | 팀장 | 컴퓨터공학부 | 201810025 | 강승구 |
# | 팀원 | 컴퓨터공학부 | 201810548 | 김인화 |
# | 팀원 | 컴퓨터공학부 | 201810930 | 박병현 |
# | 팀원 | 컴퓨터공학부 | 201810955 | 박성호 |

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# PYTHONPATH 변수 초기화
# %env PYTHONPATH=

# Miniconda 3 설치
! wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh 
! chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
! bash ./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/
# !conda install --channel defaults conda python=3.8 --yes
# !conda update --channel defaults --all --yes
import sys 
sys.path.append("/usr/local/lib/python3.8/site-packages")
# Out:
# env: PYTHONPATH=
# --2022-12-10 15:04:15--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76120962 (73M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh.2’
#
# Miniconda3-py38_4.1 100%[===================>]  72.59M   158MB/s    in 0.5s
#
# 2022-12-10 15:04:16 (158 MB/s) - ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh.2’ saved [76120962/76120962]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# /
# Found conflicts! Looking for incompatible packages.
# ...

# %% [markdown]
# #  압축파일 한번에 압축해제

# %%
import glob
import zipfile
files = glob.glob('data/clothes/*.zip')
files

for file in files:

    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall('data/raw')

# %%
# ============================== 학습 코드 작성 시작 ==============================

# %%
# ============================== 학습 코드 작성 끝 ==============================

# %%
# conda 가상 환경 Export
# !conda env export > "/content/drive/MyDrive/Colab Notebooks/k-fashion-mmdetection.yaml"
